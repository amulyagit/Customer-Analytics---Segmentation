# %%
# !pip install -U dataprep

# Python library to streamline and expedite the process of data preparation and EDA
# Out:
# Requirement already satisfied: dataprep in c:\users\amusu\anaconda3\lib\site-packages (0.4.5)
# Requirement already satisfied: pydantic<2.0,>=1.6 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (1.10.5)
# Requirement already satisfied: dask[array,dataframe,delayed]>=2022.3.0 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (2024.2.1)
# Requirement already satisfied: jinja2<3.1,>=3.0 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (3.0.3)
# Requirement already satisfied: jsonpath-ng<2.0,>=1.5 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (1.7.0)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (3.13.2)
# Requirement already satisfied: regex<2022.0.0,>=2021.8.3 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (2021.8.3)
# Requirement already satisfied: metaphone<0.7,>=0.6 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (0.6)
# Requirement already satisfied: scipy<2.0,>=1.8 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (1.13.1)
# Requirement already satisfied: sqlalchemy==1.3.24 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (1.3.24)
# Requirement already satisfied: nltk<4.0.0,>=3.6.7 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (3.9.2)
# Requirement already satisfied: bokeh<3,>=2 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (2.4.1)
# Requirement already satisfied: tqdm<5.0,>=4.48 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (4.62.3)
# Requirement already satisfied: flask<3,>=2 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (2.2.5)
# Requirement already satisfied: flask_cors<4.0.0,>=3.0.10 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (3.0.10)
# Requirement already satisfied: pydot<2.0.0,>=1.4.2 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (1.4.2)
# Requirement already satisfied: varname<0.9.0,>=0.8.1 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (0.8.3)
# Requirement already satisfied: numpy<2.0,>=1.21 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (1.26.4)
# Requirement already satisfied: pandas<2.0,>=1.1 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (1.3.4)
# Requirement already satisfied: python-stdnum<2.0,>=1.16 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (1.20)
# Requirement already satisfied: rapidfuzz<3.0.0,>=2.1.2 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (2.15.2)
# Requirement already satisfied: ipywidgets<8.0,>=7.5 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (7.6.5)
# Requirement already satisfied: wordcloud<2.0,>=1.8 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (1.8.1)
# Requirement already satisfied: python-crfsuite==0.9.8 in c:\users\amusu\anaconda3\lib\site-packages (from dataprep) (0.9.8)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\amusu\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\amusu\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (21.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\amusu\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (2.6.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\amusu\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\amusu\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.22.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\amusu\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\amusu\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (6.7.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\amusu\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (5.0.1)
# Requirement already satisfied: typing-extensions>=4.2 in c:\users\amusu\anaconda3\lib\site-packages (from aiosignal>=1.4.0->aiohttp<4.0,>=3.6->dataprep) (4.5.0)
# Requirement already satisfied: packaging>=16.8 in c:\users\amusu\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (23.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\amusu\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (8.4.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\amusu\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (6.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\amusu\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (6.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\amusu\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\amusu\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2021.10.1)
# Requirement already satisfied: partd>=1.2.0 in c:\users\amusu\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.2.0)
# Requirement already satisfied: click>=8.1 in c:\users\amusu\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (8.1.8)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\amusu\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (8.7.0)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\amusu\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.11.1)
# Requirement already satisfied: colorama in c:\users\amusu\anaconda3\lib\site-packages (from click>=8.1->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.4.4)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\amusu\anaconda3\lib\site-packages (from flask<3,>=2->dataprep) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\amusu\anaconda3\lib\site-packages (from flask<3,>=2->dataprep) (3.1.3)
# Requirement already satisfied: Six in c:\users\amusu\anaconda3\lib\site-packages (from flask_cors<4.0.0,>=3.0.10->dataprep) (1.16.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\amusu\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (3.23.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\amusu\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\amusu\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (6.4.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\amusu\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.1.3)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\amusu\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.1.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\amusu\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (7.29.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\amusu\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\amusu\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (1.0.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\amusu\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\amusu\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\amusu\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (6.1.12)
# Requirement already satisfied: jedi>=0.16 in c:\users\amusu\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\amusu\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (3.0.20)
# Requirement already satisfied: backcall in c:\users\amusu\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\amusu\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (58.0.4)
# Requirement already satisfied: pygments in c:\users\amusu\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (2.10.0)
# Requirement already satisfied: pickleshare in c:\users\amusu\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.5)
# Requirement already satisfied: decorator in c:\users\amusu\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (5.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\amusu\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\amusu\anaconda3\lib\site-packages (from jinja2<3.1,>=3.0->dataprep) (3.0.3)
# Requirement already satisfied: ply in c:\users\amusu\anaconda3\lib\site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (3.11)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\amusu\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\amusu\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\amusu\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (22.2.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\amusu\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (228)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\amusu\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\amusu\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.0)
# Requirement already satisfied: joblib in c:\users\amusu\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.6.7->dataprep) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\amusu\anaconda3\lib\site-packages (from pandas<2.0,>=1.1->dataprep) (2021.3)
# Requirement already satisfied: locket in c:\users\amusu\anaconda3\lib\site-packages\locket-0.2.1-py3.9.egg (from partd>=1.2.0->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.2.1)
# Requirement already satisfied: wcwidth in c:\users\amusu\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.5)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\amusu\anaconda3\lib\site-packages (from pydot<2.0.0,>=1.4.2->dataprep) (3.0.4)
# Requirement already satisfied: pure_eval<1.0.0 in c:\users\amusu\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.2.3)
# Requirement already satisfied: executing<0.9.0,>=0.8.3 in c:\users\amusu\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.8.3)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in c:\users\amusu\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (2.4.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\amusu\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.4.5)
# Requirement already satisfied: nbconvert in c:\users\amusu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.1.0)
# Requirement already satisfied: prometheus-client in c:\users\amusu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\amusu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\amusu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.9.4)
# Requirement already satisfied: argon2-cffi in c:\users\amusu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (20.1.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\amusu\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.7)
# Requirement already satisfied: matplotlib in c:\users\amusu\anaconda3\lib\site-packages (from wordcloud<2.0,>=1.8->dataprep) (3.4.3)
# Requirement already satisfied: idna>=2.0 in c:\users\amusu\anaconda3\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0,>=3.6->dataprep) (3.2)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\amusu\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\amusu\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.20)
# Requirement already satisfied: cycler>=0.10 in c:\users\amusu\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\amusu\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.3.1)
# Requirement already satisfied: bleach in c:\users\amusu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.0.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\amusu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\amusu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\amusu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.3)
# Requirement already satisfied: defusedxml in c:\users\amusu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\amusu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\amusu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.3)
# Requirement already satisfied: testpath in c:\users\amusu\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.0)
# Requirement already satisfied: nest-asyncio in c:\users\amusu\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\amusu\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.10)
# Requirement already satisfied: webencodings in c:\users\amusu\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)

# %%
import numpy as np
import pandas as pd
import math
from datetime import timedelta, datetime
from dataprep.clean import clean_country
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("seaborn")
plt.rcParams["figure.figsize"] = (20, 5)

# %%
df1 = pd.read_csv(r"C:\Users\amusu\Documents\APEXON_2\sales_data.csv", 
                  dtype={'week.year': str}, 
                  sep=';', 
                  decimal=',')

# %%
df1.head()
# Out:
#   country       id week.year  revenue  units
# 0      KR   702234   03.2019   808.08      1
# 1      KR   702234   06.2019  1606.80      2
# 2      KR  3618438   08.2019   803.40      1
# 3      KR  3618438   09.2019   803.40      1
# 4      KR  3618438   09.2019   803.40      1

# %%
df1.shape
# Out:
# (235574, 5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235574 entries, 0 to 235573
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   country    235574 non-null  object
#  1   id         235574 non-null  int64
#  2   week.year  235574 non-null  object
#  3   revenue    235574 non-null  float64
#  4   units      235574 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 9.0+ MB

# %%
# Splitting 'week.year' column on '.' and creating 'week' and 'year' columns

df1['week'] = df1['week.year'].astype(str).str.split('.').str[0]
df1['year'] = df1['week.year'].astype(str).str.split('.').str[1]

# %%
df1.head()
# Out:
#   country       id week.year  revenue  units week  year
# 0      KR   702234   03.2019   808.08      1   03  2019
# 1      KR   702234   06.2019  1606.80      2   06  2019
# 2      KR  3618438   08.2019   803.40      1   08  2019
# 3      KR  3618438   09.2019   803.40      1   09  2019
# 4      KR  3618438   09.2019   803.40      1   09  2019

# %%
# Converting year and week into date, using Monday as first day of the week

df1['date'] = pd.to_datetime(df1['year'].map(str) + df1['week'].map(str) + '-1', format='%Y%W-%w')

# %%
df1.columns
# Out:
# Index(['country', 'id', 'week.year', 'revenue', 'units', 'week', 'year',
#        'date'],
#       dtype='object')

# %%
# Removing unnecesary columns

df2 = df1.drop(['week.year', 'week', 'year'], axis=1)

# %%
df2.head()
# Out:
#   country       id  revenue  units       date
# 0      KR   702234   808.08      1 2019-01-21
# 1      KR   702234  1606.80      2 2019-02-11
# 2      KR  3618438   803.40      1 2019-02-25
# 3      KR  3618438   803.40      1 2019-03-04
# 4      KR  3618438   803.40      1 2019-03-04

# %%
#Rename columns

df2.rename({'revenue': 'monetary'}, axis="columns", inplace=True)
df2.head()
# Out:
#   country       id  monetary  units       date
# 0      KR   702234    808.08      1 2019-01-21
# 1      KR   702234   1606.80      2 2019-02-11
# 2      KR  3618438    803.40      1 2019-02-25
# 3      KR  3618438    803.40      1 2019-03-04
# 4      KR  3618438    803.40      1 2019-03-04

# %%
df2.describe()

## round off values
# Out:
#                  id      monetary          units
# count  2.355740e+05  2.355740e+05  235574.000000
# mean   3.193118e+06  2.840211e+03       8.599642
# std    7.371744e+06  2.247532e+04     602.939290
# min    6.000180e+05 -1.061539e+05 -150000.000000
# 25%    2.214396e+06  3.994800e+02       1.000000
# 50%    3.140856e+06  1.150320e+03       1.000000
# 75%    3.892650e+06  2.216160e+03       2.000000
# max    2.419308e+08  2.415857e+06  150000.000000

# %% [markdown]
# #### We have 235574 transactions in the period of time icluded in the dataset
# #### Biggest transaction was 150,000 units. But it seems there was a return of that amount as well, -150,000 units
# #### Most expensive purchase was 2.41 Millions

# %%
df2.isnull().sum()
# Out:
# country     0
# id          0
# monetary    0
# units       0
# date        0
# dtype: int64

# %%
df2['date'].min()
# Out:
# Timestamp('2019-01-07 00:00:00')

# %%
df2['date'].max()
# Out:
# Timestamp('2020-11-30 00:00:00')

# %%
# How many different countries we have sales in that period

df2['country'].unique()
# Out:
# array(['KR', 'PK', 'MM', 'VN', 'IN', 'SA', 'PH', 'AF', 'CN', 'BD', 'ID',
#        'TH', 'IQ', 'MY', 'JP', 'IR', 'TR', 'UZ'], dtype=object)

# %%
df2['country'].nunique()
# Out:
# 18

# %%
# Transforming country codes into full country names with clean_country function from dataprep library

clean_country(df2, "country")['country_clean'].unique()
# Out:
# C:\Users\amusu\anaconda3\lib\site-packages\dask\dataframe\core.py:7365: FutureWarning: Meta is not valid, `map_partitions` and `map_overlap` expects output to be a pandas object. Try passing a pandas object as meta or a dict or tuple representing the (name, dtype) of the columns. In the future the meta you passed will not work.
#   warnings.warn(
#   0%|          | 0/8 [00:00<?, ?it/s]
# Country Cleaning Report:
# 	235574 values cleaned (100.0%)
# Result contains 235574 (100.0%) values in the correct format and 0 null values (0.0%)
# array(['South Korea', 'Pakistan', 'Myanmar', 'Vietnam', 'India',
#        'Saudi Arabia', 'Philippines', 'Afghanistan', 'China',
#        'Bangladesh', 'Indonesia', 'Thailand', 'Iraq', 'Malaysia', 'Japan',
#        'Iran', 'Turkey', 'Uzbekistan'], dtype=object)

# %%
# Total number of customers in all countries

df2['id'].nunique()
# Out:
# 21837

# %%
# Putting date into the index for plotting the time series

df2b = df2.set_index("date")
df2b.head()
# Out:
#            country       id  monetary  units
# date
# 2019-01-21      KR   702234    808.08      1
# 2019-02-11      KR   702234   1606.80      2
# 2019-02-25      KR  3618438    803.40      1
# 2019-03-04      KR  3618438    803.40      1
# 2019-03-04      KR  3618438    803.40      1

# %%
plt.style.use('ggplot')
plt.title('Units sold per week')
plt.ylabel('units')
plt.xlabel('date');
df2b['units'].plot(figsize=(20,5), c='dodgerblue');

# %%
plt.style.use('ggplot')
plt.title('Revenue per week')
plt.ylabel('units')
plt.xlabel('date');
df2b['monetary'].plot(figsize=(20,5), c='dodgerblue');

# %%
# For greater visibility in the plots we convert the dates to monthly periods and we aggregate the units and revenue of the same period

df2c = df2b.to_period("M")

# %%
df2c.head()
# Out:
#         country       id  monetary  units
# date
# 2019-01      KR   702234    808.08      1
# 2019-02      KR   702234   1606.80      2
# 2019-02      KR  3618438    803.40      1
# 2019-03      KR  3618438    803.40      1
# 2019-03      KR  3618438    803.40      1

# %%
plt.style.use('ggplot')
df2c['units'].groupby('date').agg(sum).plot(figsize=(20,5), c='dodgerblue')
plt.title('Units sold per month')
plt.ylabel('units')
plt.xlabel('date');

# %%
plt.style.use('ggplot')
df2c['monetary'].groupby('date').agg(sum).plot(figsize=(20,5), c='dodgerblue')
plt.title('Revenue per month')
plt.ylabel('revenue')
plt.xlabel('date');

# %% [markdown]
# Revenue peaked during November 2019, due to increased purchases during Thanksgiving

# %% [markdown]
# ### Transform data to obtain RFM

# %%
print('Sales from {} to {}'.format(df2['date'].min(),
                                    df2['date'].max()))
# Out:
# Sales from 2019-01-07 00:00:00 to 2020-11-30 00:00:00

# %%
#Sales from last 365 days since most recent date

period = 365
date_N_days_ago = df2['date'].max() - timedelta(days=period)

# %%
# Remove the rows with dates older than 365 days ago

df2 = df2[df2['date']> date_N_days_ago]

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2.head()
# Out:
#   country       id  monetary  units       date
# 0      KR  4375152    773.58      1 2019-12-16
# 1      KR   705462    337.26      1 2019-12-09
# 2      KR   705462    337.26      1 2019-12-23
# 3      KR   705462    421.56      2 2019-12-16
# 4      KR   706854    391.50      1 2019-12-09

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124640 entries, 0 to 124639
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   country   124640 non-null  object
#  1   id        124640 non-null  int64
#  2   monetary  124640 non-null  float64
#  3   units     124640 non-null  int64
#  4   date      124640 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 4.8+ MB

# %%
# There are customers with the same 'id' in several countries. This causes errors in the monetary values
# Create a unique 'id+' identifier that combines country code and customer id

df3 = df2.copy()

df3['id+'] = df3['country'].map(str) + df3['id'].map(str)

# %%
df3.head()
# Out:
#   country       id  monetary  units       date        id+
# 0      KR  4375152    773.58      1 2019-12-16  KR4375152
# 1      KR   705462    337.26      1 2019-12-09   KR705462
# 2      KR   705462    337.26      1 2019-12-23   KR705462
# 3      KR   705462    421.56      2 2019-12-16   KR705462
# 4      KR   706854    391.50      1 2019-12-09   KR706854

# %%
# We set the NOW date one day after the last sale

NOW = df3['date'].max() + timedelta(days=1)
NOW
# Out:
# Timestamp('2020-12-01 00:00:00')

# %%
# Add a column, 'days_since_last_purchase', with the days between purchase date and the latest date

df3['days_since_purchase'] = df3['date'].apply(lambda x:(NOW - x).days)

# %%
df3.head()
# Out:
#   country       id  monetary  units       date        id+  days_since_purchase
# 0      KR  4375152    773.58      1 2019-12-16  KR4375152                  351
# 1      KR   705462    337.26      1 2019-12-09   KR705462                  358
# 2      KR   705462    337.26      1 2019-12-23   KR705462                  344
# 3      KR   705462    421.56      2 2019-12-16   KR705462                  351
# 4      KR   706854    391.50      1 2019-12-09   KR706854                  358

# %%
df3[df3['id+']=='KR706854']
# Out:
#       country      id  monetary  units       date       id+  \
# 4          KR  706854    391.50      1 2019-12-09  KR706854
# 5          KR  706854    388.68      1 2019-12-30  KR706854
# 14169      KR  706854    369.66      1 2020-04-06  KR706854
# 14192      KR  706854    374.76      1 2020-07-27  KR706854
# 14210      KR  706854    371.82      1 2020-11-09  KR706854
#
#        days_since_purchase
# 4                      358
# 5                      337
# 14169                  239
# 14192                  127
# 14210                   22

# %%
# Recency will be the minimum of 'days_since_last_purchase' for each customer
# Frequency will be the total number of orders in the period for each customer

aggr = {
    'days_since_purchase': lambda x:x.min(),
    'date': lambda x: len([d for d in x if d >= NOW - timedelta(days=period)])
}

# %%
aggr
# Out:
# {'days_since_purchase': <function __main__.<lambda>(x)>,
#  'date': <function __main__.<lambda>(x)>}

# %%
rfm = df3.groupby(['id', 'id+', 'country']).agg(aggr).reset_index()
rfm.rename(columns={'days_since_purchase': 'recency',
                   'date': 'frequency'},
          inplace=True)

# %%
rfm
# Out:
#               id          id+ country  recency  frequency
# 0         600018     CN600018      CN       29          7
# 1         600060     CN600060      CN      155          1
# 2         600462     CN600462      CN      211          2
# 3         600888     CN600888      CN        8          3
# 4         601014     CN601014      CN      225          1
# ...          ...          ...     ...      ...        ...
# 16564  241575552  IQ241575552      IQ       15          1
# 16565  241794972  IQ241794972      IQ      351          1
# 16566  241888554  IQ241888554      IQ       43          1
# 16567  241900254  IQ241900254      IQ        8         62
# 16568  241930824  IQ241930824      IQ       36          2
#
# [16569 rows x 5 columns]

# %%
# We check customers with id 3790218 have different recency and frequency values per country

rfm[rfm['id']==3790218]
# Out:
#             id        id+ country  recency  frequency
# 11057  3790218  AF3790218      AF      309          1
# 11058  3790218  BD3790218      BD      176          4
# 11059  3790218  CN3790218      CN        1         60
# 11060  3790218  ID3790218      ID      260          9
# 11061  3790218  IQ3790218      IQ      176          1
# 11062  3790218  MM3790218      MM      183          3
# 11063  3790218  PH3790218      PH      127          3
# 11064  3790218  PK3790218      PK       43          5
# 11065  3790218  TH3790218      TH      295          1
# 11066  3790218  TR3790218      TR       29         10
# 11067  3790218  VN3790218      VN      302          1

# %%
# We get the revenue of the last 365 days per customer

df3[df3['date'] >= NOW - timedelta(days=period)]\
    .groupby('id+')['monetary'].sum()
# Out:
# id+
# AF186035892       277.86
# AF1915092      250651.86
# AF1915920        2238.60
# AF1916280         612.78
# AF1917144       29793.18
#                  ...
# VN991620         1093.86
# VN993528         1018.86
# VN993996         4037.28
# VN995010          544.32
# VN998130          384.84
# Name: monetary, Length: 16569, dtype: float64

# %%
# Getting only the monetary value for specific customer with id 3790218

df3[ (df3['id'] == 3790218) & (df3['date'] >= NOW - timedelta(days=period))]\
    .groupby('id+')['monetary'].sum()
# Out:
# id+
# AF3790218      9706.08
# BD3790218      7267.38
# CN3790218    716199.60
# ID3790218     49154.22
# IQ3790218      1243.08
# MM3790218      7110.60
# PH3790218      1013.58
# PK3790218    211108.20
# TH3790218      1245.48
# TR3790218     16072.02
# VN3790218      3377.34
# Name: monetary, dtype: float64

# %%
# We add the revenue from df3 of last period per customer to rfm dataframe

rfm['monetary'] = rfm['id+']\
    .apply(lambda x: df3[ (df3['id+'] == x) & (df3['date'] >= NOW - timedelta(days=period))]\
    .groupby(['id', 'country']).sum().iloc[0,0])

# %%
rfm.head()
# Out:
#        id       id+ country  recency  frequency  monetary
# 0  600018  CN600018      CN       29          7  21402.78
# 1  600060  CN600060      CN      155          1   1201.14
# 2  600462  CN600462      CN      211          2   2033.64
# 3  600888  CN600888      CN        8          3   2335.80
# 4  601014  CN601014      CN      225          1    230.52

# %%
# Checking monetary value is correct by checking on our biggest customer

rfm[rfm['monetary']==rfm['monetary'].max()]
# Out:
#          id       id+ country  recency  frequency     monetary
# 173  638544  CN638544      CN        1        217  21482332.56

# %%
rfm[rfm['frequency']==rfm['frequency'].max()]
# Out:
#            id        id+ country  recency  frequency    monetary
# 8290  3249114  TR3249114      TR        1       1351  2731448.04

# %%
# We check that customers with id 3790218 get a different monetary value per country

rfm[rfm['id']==3790218]
# Out:
#             id        id+ country  recency  frequency   monetary
# 11057  3790218  AF3790218      AF      309          1    9706.08
# 11058  3790218  BD3790218      BD      176          4    7267.38
# 11059  3790218  CN3790218      CN        1         60  716199.60
# 11060  3790218  ID3790218      ID      260          9   49154.22
# 11061  3790218  IQ3790218      IQ      176          1    1243.08
# 11062  3790218  MM3790218      MM      183          3    7110.60
# 11063  3790218  PH3790218      PH      127          3    1013.58
# 11064  3790218  PK3790218      PK       43          5  211108.20
# 11065  3790218  TH3790218      TH      295          1    1245.48
# 11066  3790218  TR3790218      TR       29         10   16072.02
# 11067  3790218  VN3790218      VN      302          1    3377.34

# %%
# Let's frop the column 'id+'

rfm.drop(['id+'], axis=1, inplace=True)

# %% [markdown]
# ### Calculating R, F and M scores

# %%
# Assign a score between 1 and 5 depending on recency, monetary and frequency parameters
# Use the quintiles method, dividing every feature on groups that contain 20 % of the samples

quintiles = rfm[['recency', 'frequency', 'monetary']].quantile([.2, .4, .6, .8]).to_dict()
quintiles

# why?
# Out:
# {'recency': {0.2: 15.0, 0.4: 50.0, 0.6: 120.0, 0.8: 239.0},
#  'frequency': {0.2: 1.0, 0.4: 2.0, 0.6: 4.0, 0.8: 9.0},
#  'monetary': {0.2: 967.5,
#   0.4: 2212.2,
#   0.6: 4852.548000000001,
#   0.8: 13957.500000000004}}

# %%
# Assigning scores from 1 to 5
# Higher values are better for frequency and monetary, while lower values are better for recency

def r_score(x):
    if x <= quintiles['recency'][.2]:
        return 5
    elif x <= quintiles['recency'][.4]:
        return 4
    elif x <= quintiles['recency'][.6]:
        return 3
    elif x <= quintiles['recency'][.8]:
        return 2
    else:
        return 1

# %%
def fm_score(x, c):
    if x <= quintiles[c][.2]:
        return 1
    elif x <= quintiles[c][.4]:
        return 2
    elif x <= quintiles[c][.6]:
        return 3
    elif x <= quintiles[c][.8]:
        return 4
    else:
        return 5

# %%
# We asssign R, F and M scores to each customer

rfm['r'] = rfm['recency'].apply(lambda x: r_score(x))
rfm['f'] = rfm['frequency'].apply(lambda x: fm_score(x, 'frequency'))
rfm['m'] = rfm['monetary'].apply(lambda x: fm_score(x, 'monetary'))

# %%
rfm.head()
# Out:
#        id country  recency  frequency  monetary  r  f  m
# 0  600018      CN       29          7  21402.78  4  4  5
# 1  600060      CN      155          1   1201.14  2  1  2
# 2  600462      CN      211          2   2033.64  2  2  2
# 3  600888      CN        8          3   2335.80  5  3  3
# 4  601014      CN      225          1    230.52  2  1  1

# %%
# Combine R, F and M scores to create a unique RFM score

rfm['rfm_score'] = rfm['r'].map(str) + rfm['f'].map(str) + rfm['m'].map(str)
rfm.head()
# Out:
#        id country  recency  frequency  monetary  r  f  m rfm_score
# 0  600018      CN       29          7  21402.78  4  4  5       445
# 1  600060      CN      155          1   1201.14  2  1  2       212
# 2  600462      CN      211          2   2033.64  2  2  2       222
# 3  600888      CN        8          3   2335.80  5  3  3       533
# 4  601014      CN      225          1    230.52  2  1  1       211

# %% [markdown]
# With this rfm scores we would have 125 segments of customers
#
# To make a more simple segment map of 11 segments, we combine f and m scores, rounding them down
#
# fm = (f+m)/2

# %%
def truncate(x):
    return math.trunc(x)

# %%
rfm['fm'] = ((rfm['f'] + rfm['m'])/2).apply(lambda x: truncate(x))

# %%
rfm.head()
# Out:
#        id country  recency  frequency  monetary  r  f  m rfm_score  fm
# 0  600018      CN       29          7  21402.78  4  4  5       445   4
# 1  600060      CN      155          1   1201.14  2  1  2       212   1
# 2  600462      CN      211          2   2033.64  2  2  2       222   2
# 3  600888      CN        8          3   2335.80  5  3  3       533   3
# 4  601014      CN      225          1    230.52  2  1  1       211   1

# %% [markdown]
# ### Segment Description
# #### Champions Bought recently, buy often and spend the most
# #### Loyal Customers Buy on a regular basis. Responsive to promotions.
# #### Potential Loyalists Recent customers with average frequency.
# #### Recent Customers Bought most recently, but not often.
# #### Promising Recent shoppers, but haven’t spent much.
# #### Customers Needing Attention Above average recency, frequency and monetary values. May not have bought very recently though.
# #### About To Sleep Below average recency and frequency. Will lose them if not reactivated.
# #### At Risk Purchased often but a long time ago. Need to bring them back!
# #### Can’t Lose Them Used to purchase frequently but haven’t returned for a long time.
# #### Hibernating Last purchase was long back and low number of orders.
# #### Lost Purchased long time ago and never came back.

# %%
# We create a segment map of only 11 segments based on only two scores: 'r' and 'fm'

segment_map = {
    r'22': 'hibernating',
    r'[1-2][1-2]': 'lost',
    r'15': 'can\'t lose',
    r'[1-2][3-5]': 'at risk',
    r'3[1-2]': 'about to sleep',
    r'33': 'need attention',
    r'55': 'champions',
    r'[3-5][4-5]': 'loyal customers',
    r'41': 'promising',
    r'51': 'new customers',
    r'[4-5][2-3]': 'potential loyalists'
}

rfm['segment'] = rfm['r'].map(str) + rfm['fm'].map(str)
rfm['segment'] = rfm['segment'].replace(segment_map, regex=True)
rfm.head()
# Out:
#        id country  recency  frequency  monetary  r  f  m rfm_score  fm  \
# 0  600018      CN       29          7  21402.78  4  4  5       445   4
# 1  600060      CN      155          1   1201.14  2  1  2       212   1
# 2  600462      CN      211          2   2033.64  2  2  2       222   2
# 3  600888      CN        8          3   2335.80  5  3  3       533   3
# 4  601014      CN      225          1    230.52  2  1  1       211   1
#
#                segment
# 0      loyal customers
# 1                 lost
# 2          hibernating
# 3  potential loyalists
# 4                 lost

# %%
rfm.isnull().sum()
# Out:
# id           0
# country      0
# recency      0
# frequency    0
# monetary     0
# r            0
# f            0
# m            0
# rfm_score    0
# fm           0
# segment      0
# dtype: int64

# %%
rfm['segment'].unique()
# Out:
# array(['loyal customers', 'lost', 'hibernating', 'potential loyalists',
#        'new customers', 'need attention', 'at risk', 'champions',
#        'about to sleep', 'promising', "can't lose"], dtype=object)

# %%
# We take a look on some segments

rfm[rfm['segment']=="can't lose"].sort_values(by='monetary', ascending=False)
# Out:
#             id country  recency  frequency   monetary  r  f  m rfm_score  fm  \
# 13028  4096386      JP      260        105  220267.86  1  5  5       155   5
# 3502   2443284      IN      246         10  102208.02  1  5  5       155   5
# 14174  4262646      IN      316         10   91909.44  1  5  5       155   5
# 2435   1803672      IN      267         12   70506.96  1  5  5       155   5
# 13254  4132968      VN      253         26   42535.14  1  5  5       155   5
# 11222  3815274      IN      267         11   37968.72  1  5  5       155   5
# 1458   1031454      PH      267         23   31833.30  1  5  5       155   5
# 5437   2809158      IN      274         12   27150.12  1  5  5       155   5
# 14644  4326906      IN      337         11   22351.68  1  5  5       155   5
# 259     668070      MM      267         11   21886.92  1  5  5       155   5
# 15331  4418268      SA      302         10   14295.54  1  5  5       155   5
#
#           segment
# 13028  can't lose
# 3502   can't lose
# 14174  can't lose
# 2435   can't lose
# 13254  can't lose
# 11222  can't lose
# 1458   can't lose
# 5437   can't lose
# 14644  can't lose
# 259    can't lose
# 15331  can't lose

# %%
rfm[rfm['segment']=="need attention"].sort_values(by='monetary', ascending=False).head(10)
# Out:
#             id country  recency  frequency  monetary  r  f  m rfm_score  fm  \
# 8245   3242664      TR       64          1  73823.58  3  1  5       315   3
# 13065  4107798      JP      120          2  67257.48  3  2  5       325   3
# 9847   3561900      ID      120          1  59700.00  3  1  5       315   3
# 6626   2921070      ID       71          2  34730.22  3  2  5       325   3
# 10009  3587772      CN       92          1  29961.00  3  1  5       315   3
# 3087   2131194      JP       57          1  28543.74  3  1  5       315   3
# 13463  4160490      JP       99          1  24842.22  3  1  5       315   3
# 1251    993414      KR       71          2  22018.32  3  2  5       325   3
# 3936   2544588      BD       71          2  19043.82  3  2  5       325   3
# 3616   2468010      TH       85          2  18599.58  3  2  5       325   3
#
#               segment
# 8245   need attention
# 13065  need attention
# 9847   need attention
# 6626   need attention
# 10009  need attention
# 3087   need attention
# 13463  need attention
# 1251   need attention
# 3936   need attention
# 3616   need attention

# %%
rfm[rfm['segment']=='loyal customers'].sort_values(by='monetary', ascending=False).head(10)
# Out:
#             id country  recency  frequency    monetary  r  f  m rfm_score  fm  \
# 15420  4422780      TR       92         13  2315341.14  3  5  5       355   5
# 2882   2030526      JP       22         50  1519339.86  4  5  5       455   5
# 3220   2182446      JP       29         18  1492057.68  4  5  5       455   5
# 12660  4041366      PK       50          9   736626.96  4  4  5       445   4
# 5612   2853774      VN        8          6   712230.00  5  4  5       545   4
# 10343  3649728      PH       29         81   579167.52  4  5  5       455   5
# 8284   3248568      TR       64          3   573792.72  3  3  5       335   4
# 15450  4427148      IN       29         14   502843.32  4  5  5       455   5
# 14678  4332210      ID       43         21   474773.40  4  5  5       455   5
# 2802   1985592      IQ       78          4   460390.86  3  3  5       335   4
#
#                segment
# 15420  loyal customers
# 2882   loyal customers
# 3220   loyal customers
# 12660  loyal customers
# 5612   loyal customers
# 10343  loyal customers
# 8284   loyal customers
# 15450  loyal customers
# 14678  loyal customers
# 2802   loyal customers

# %%
rfm[rfm['segment']=='champions'].sort_values(by='monetary', ascending=False).head(10)
# Out:
#             id country  recency  frequency     monetary  r  f  m rfm_score  \
# 173     638544      CN        1        217  21482332.56  5  5  5       555
# 15436  4424580      CN        1        104  16912322.46  5  5  5       555
# 14754  4341960      TR        1        200  16550997.90  5  5  5       555
# 11942  3929094      ID        1        470   8748884.64  5  5  5       555
# 9626   3520734      JP        1        198   6207519.96  5  5  5       555
# 15915  4494150      TR        1         57   4874668.14  5  5  5       555
# 10168  3618438      KR        8       1020   4615660.08  5  5  5       555
# 14027  4245048      PH        1        993   4358515.98  5  5  5       555
# 3050   2111100      IN        1        876   4270717.80  5  5  5       555
# 11742  3894492      PH        8         63   4106366.22  5  5  5       555
#
#        fm    segment
# 173     5  champions
# 15436   5  champions
# 14754   5  champions
# 11942   5  champions
# 9626    5  champions
# 15915   5  champions
# 10168   5  champions
# 14027   5  champions
# 3050    5  champions
# 11742   5  champions

# %%
rfm['monetary'].mean()
# Out:
# 21629.611149737302

# %%
# Customers with monetary over the average that need attention

rfm[(rfm['monetary']>rfm['monetary'].mean()) & (rfm['segment']=='need attention')]\
    .sort_values(by='monetary', ascending=False)
# Out:
#             id country  recency  frequency  monetary  r  f  m rfm_score  fm  \
# 8245   3242664      TR       64          1  73823.58  3  1  5       315   3
# 13065  4107798      JP      120          2  67257.48  3  2  5       325   3
# 9847   3561900      ID      120          1  59700.00  3  1  5       315   3
# 6626   2921070      ID       71          2  34730.22  3  2  5       325   3
# 10009  3587772      CN       92          1  29961.00  3  1  5       315   3
# 3087   2131194      JP       57          1  28543.74  3  1  5       315   3
# 13463  4160490      JP       99          1  24842.22  3  1  5       315   3
# 1251    993414      KR       71          2  22018.32  3  2  5       325   3
#
#               segment
# 8245   need attention
# 13065  need attention
# 9847   need attention
# 6626   need attention
# 10009  need attention
# 3087   need attention
# 13463  need attention
# 1251   need attention

# %%
# Scatter plot to explore the distribution of customers
# Using 'monetary' as the size of the points, we see that the majority of customers who spend the most also purchase more frequently

plt.style.use('ggplot')
rfm.plot.scatter(x='recency', y='frequency', s=rfm['monetary']*5e-5, figsize=(20,5), c='dodgerblue')
plt.gca().set(xlabel='recency', ylabel='frequency', title='Customer distribution');
# Out:
# C:\Users\amusu\anaconda3\lib\site-packages\matplotlib\collections.py:1003: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
# Eport the dataframe to a CSV file for Power BI
# (Aded the parameter float_format='%.2f' for setting numbers to two decimals)

rfm.to_csv('rfm_segmentation.csv', encoding='utf-8', index=False, float_format='%.2f')
